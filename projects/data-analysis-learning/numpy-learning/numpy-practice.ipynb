# %% [markdown]
# # 2.4 综合练习
#
# > 共 10 道题，覆盖 NumPy 常用操作：统计、矩阵运算、随机数、数组变形、布尔索引、拼接、唯一值、缺失值处理。

# %% [markdown]
# ## 题目 1：温度数据分析
#
# 某城市一周的最高气温（℃）为 `[28, 30, 29, 31, 32, 30, 29]`。
#
# - 计算平均气温、最高气温和最低气温。
# - 找出气温超过 30℃ 的天数。
#
# 💡 **提示**：`np.mean()` / `np.max()` / `np.min()` / 布尔索引 `arr[arr > 30]`

# %%
import numpy as np

temps = np.array([28, 30, 29, 31, 32, 30, 29])

# 你的代码在这里

# %% [markdown]
# ## 题目 2：学生成绩统计
#
# 某班级 5 名学生的数学成绩为 `[85, 90, 78, 92, 88]`。
#
# - 计算成绩的平均分、中位数和标准差。
# - 将成绩转换为百分制（假设满分为 100）。
#
# 💡 **提示**：`np.mean()` / `np.median()` / `np.std()`

# %%
scores = np.array([85, 90, 78, 92, 88])

# 你的代码在这里

# %% [markdown]
# ## 题目 3：矩阵运算
#
# 给定矩阵 A = [[1, 2], [3, 4]] 和 B = [[5, 6], [7, 8]]。
#
# - 计算 A + B 和 A * B（逐元素乘法）。
# - 计算 A 和 B 的矩阵乘法（点积）。
#
# 💡 **提示**：`+` `*` 是逐元素运算，`@` 或 `np.dot()` 是矩阵乘法

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])

# 你的代码在这里

# %% [markdown]
# ## 题目 4：随机数据生成
#
# 生成一个 (3, 4) 的随机整数数组，范围 [0, 10)。
#
# - 计算每列的**最大值**和每行的**最小值**。
# - 将数组中的所有奇数替换为 -1。
#
# 💡 **提示**：`np.random.randint()` / `np.max(axis=0)` / `np.min(axis=1)` / 布尔索引 `arr[arr % 2 == 1]`

# %%
# 固定种子，保证可复现
np.random.seed(42)
arr = np.random.randint(0, 10, (3, 4))

# 你的代码在这里

# %% [markdown]
# ## 题目 5：数组变形
#
# 创建一个 1 到 12 的一维数组，并转换为 (3, 4) 的二维数组。
#
# - 计算每行的**和**与每列的**平均值**。
# - 将数组展平为一维数组。
#
# 💡 **提示**：`np.arange(1, 13).reshape(3, 4)` / `np.sum(axis=1)` / `np.mean(axis=0)` / `.flatten()`

# %%
# 你的代码在这里

# %% [markdown]
# ## 题目 6：布尔索引
#
# 生成一个 (5, 5) 的随机数组，范围 [0, 20)。
#
# - 找出数组中**大于 10** 的元素。
# - 将所有大于 10 的元素替换为 0。
#
# 💡 **提示**：`arr[arr > 10]` 筛选 / `arr[arr > 10] = 0` 直接替换

# %%
np.random.seed(42)
arr = np.random.randint(0, 20, (5, 5))

# 你的代码在这里

# %% [markdown]
# ## 题目 7：统计函数应用
#
# 某公司 6 个月的销售额（万元）为 `[120, 135, 110, 125, 130, 140]`。
#
# - 计算销售额的总和、均值和方差。
# - 找出销售额**最高**的月份和**最低**的月份（第几个月）。
#
# 💡 **提示**：`np.sum()` / `np.mean()` / `np.var()` / `np.argmax()` / `np.argmin()`

# %%
sales = np.array([120, 135, 110, 125, 130, 140])

# 你的代码在这里

# %% [markdown]
# ## 题目 8：数组拼接
#
# 给定 `A = [1, 2, 3]` 和 `B = [4, 5, 6]`。
#
# - **水平拼接**为 `[1, 2, 3, 4, 5, 6]`。
# - **垂直拼接**为 `[[1, 2, 3], [4, 5, 6]]`。
#
# 💡 **提示**：`np.concatenate()` / `np.vstack()`

# %%
A, B = np.array([1, 2, 3]), np.array([4, 5, 6])

# 你的代码在这里

# %% [markdown]
# ## 题目 9：唯一值与排序
#
# 给定数组 `[2, 1, 2, 3, 1, 4, 3]`。
#
# - 找出唯一值并排序。
# - 计算每个唯一值出现的次数。
#
# 💡 **提示**：`np.unique(arr, return_counts=True)`

# %%
arr = np.array([2, 1, 2, 3, 1, 4, 3])

# 你的代码在这里

# %% [markdown]
# ## 题目 10：缺失值处理
#
# 给定数组 `[1, np.nan, 3, np.nan, 5]`。
#
# - 计算**非缺失值**的数量。
# - 将缺失值替换为 0。
#
# 💡 **提示**：`np.isnan()` / `~np.isnan()` / 布尔索引直接赋值

# %%
arr = np.array([1, np.nan, 3, np.nan, 5])

# 你的代码在这里

# %% [markdown]
# ---
#
# ## 参考答案
#
# > 先自己动手做，卡住了再看答案。做完对照着验证思路。

# %% [markdown]
# ### 题 1 答案

# %%
temps = np.array([28, 30, 29, 31, 32, 30, 29])
print("平均气温:", np.mean(temps))   # 29.857
print("最高气温:", np.max(temps))    # 32
print("最低气温:", np.min(temps))    # 28
print("超过30℃的天数:", len(temps[temps > 30]))  # 2

# %% [markdown]
# ### 题 2 答案

# %%
scores = np.array([85, 90, 78, 92, 88])
print("平均分:", np.mean(scores))      # 86.6
print("中位数:", np.median(scores))    # 88
print("标准差:", np.std(scores))       # 4.98
# 成绩本身已是百分制，无需转换

# %% [markdown]
# ### 题 3 答案

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([[5, 6], [7, 8]])
print("A + B:\n", A + B)    # [[6, 8], [10, 12]]
print("A * B:\n", A * B)    # [[5, 12], [21, 32]]（逐元素）
print("A @ B:\n", A @ B)    # [[19, 22], [43, 50]]（矩阵乘）

# %% [markdown]
# ### 题 4 答案

# %%
np.random.seed(42)
arr = np.random.randint(0, 10, (3, 4))
print("原数组:\n", arr)
print("每列最大值:", np.max(arr, axis=0))
print("每行最小值:", np.min(arr, axis=1))
arr_copy = arr.copy()
arr_copy[arr_copy % 2 == 1] = -1   # 奇数替换为 -1
print("替换后:\n", arr_copy)

# %% [markdown]
# ### 题 5 答案

# %%
arr = np.arange(1, 13).reshape(3, 4)
print("数组:\n", arr)
print("每行和:", np.sum(arr, axis=1))    # [10, 26, 42]
print("每列均值:", np.mean(arr, axis=0))  # [5, 6, 7, 8]
print("展平后:", arr.flatten())           # [1, 2, ..., 12]

# %% [markdown]
# ### 题 6 答案

# %%
np.random.seed(42)
arr = np.random.randint(0, 20, (5, 5))
print(">10的元素:", arr[arr > 10])
arr_copy = arr.copy()
arr_copy[arr_copy > 10] = 0
print("替换后:\n", arr_copy)

# %% [markdown]
# ### 题 7 答案

# %%
sales = np.array([120, 135, 110, 125, 130, 140])
print("总和:", np.sum(sales))           # 760
print("均值:", np.mean(sales))           # 126.67
print("方差:", np.var(sales))            # 108.89
print("最高月份:", np.argmax(sales) + 1) # 6
print("最低月份:", np.argmin(sales) + 1) # 3

# %% [markdown]
# ### 题 8 答案

# %%
A, B = np.array([1, 2, 3]), np.array([4, 5, 6])
print("水平拼接:", np.concatenate((A, B)))         # [1, 2, 3, 4, 5, 6]
print("垂直拼接:\n", np.vstack((A, B)))            # [[1,2,3], [4,5,6]]

# %% [markdown]
# ### 题 9 答案

# %%
arr = np.array([2, 1, 2, 3, 1, 4, 3])
unique_values, counts = np.unique(arr, return_counts=True)
print("唯一值:", unique_values)   # [1, 2, 3, 4]
print("出现次数:", counts)        # [2, 2, 2, 1]

# %% [markdown]
# ### 题 10 答案

# %%
arr = np.array([1, np.nan, 3, np.nan, 5])
print("非缺失值数量:", np.sum(~np.isnan(arr)))  # 3
arr_copy = arr.copy()
arr_copy[np.isnan(arr_copy)] = 0                 # 替换为 0
print("替换后:", arr_copy)                       # [1, 0, 3, 0, 5]
